# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns
import statsmodels.api as sm
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv('E11.csv')
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)
data.describe()
y=data.nunique()
w= data.apply(lambda col: col.astype(str).str.count('#REF!')).sum().drop(columns=['c82','c110'])
x=data.isnull().sum().drop(columns=['c82','c110'])
z=x+w
z1=z[z>0]
y[y<10].plot(kind='bar')

# %%
data=pd.read_csv('E11.csv')
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)
data.describe()
y=data.nunique()
w= data.apply(lambda col: col.astype(str).str.count('#REF!')).sum().drop(columns=['c82','c110'])
x=data.isnull().sum().drop(columns=['c82','c110'])
z=x+w
z1=z[z>0]
x[x>50].plot(kind='bar')

# %%
data=pd.read_csv('E11.csv')
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)
data.describe()
y=data.nunique()
w= data.apply(lambda col: col.astype(str).str.count('#REF!')).sum().drop(columns=['c82','c110'])
x=data.isnull().sum().drop(columns=['c82','c110'])
z=x+w
z1=z[z>0]
z1[z<50].plot(kind='bar')

# %%
manage=[]

first_nan = 563
numberofnan = 13
for i in range(numberofnan+2):
    manage.append(data['c57'][first_nan-1+i])
for i in range(numberofnan):
    data['c57'][first_nan+i]=np.round(manage[0]-(manage[0]-manage[numberofnan+1])/numberofnan*i,9)
    manage[1+i]=np.round(manage[0]-(manage[0]-manage[numberofnan+1])/numberofnan*i,9)
y=data['c57'][550:590]
x=np.arange(1,len(y)+1)
plt.plot(x,y)
data['c57']

# %%
manage=[]
first_nan = 548
numberofnan = 33
for i in range(numberofnan+2):
    manage.append(data['c59'][first_nan-1+i])
for i in range(numberofnan):
    data['c59'][first_nan+i]=np.round(manage[0]-(manage[0]-manage[numberofnan+1])/numberofnan*i,9)

# %%
manage=[]
first_nan = 580
numberofnan = 3
for i in range(numberofnan):
    data['c88'][first_nan+i]=0
for i in range(numberofnan+2):
    manage.append(float(data['c88'][first_nan-1+i]))
for i in range(numberofnan):
    data['c88'][first_nan+i]=np.round(manage[0]-(manage[0]-manage[numberofnan+1])/numberofnan*i,9)

# %%
manage=[]
first_nan = 580
numberofnan = 3
for i in range(numberofnan):
    data['c96'][first_nan+i]=0
for i in range(numberofnan+2):
    manage.append(float(data['c96'][first_nan-1+i]))
for i in range(numberofnan):
    data['c96'][first_nan+i]=np.round(manage[0]-(manage[0]-manage[numberofnan+1])/numberofnan*i,9)

# %%
manage=[]
first_nan = 580
numberofnan = 3
for i in range(numberofnan):
    data['c97'][first_nan+i]=0
for i in range(numberofnan+2):
    manage.append(float(data['c97'][first_nan-1+i]))
for i in range(numberofnan):
    data['c97'][first_nan+i]=np.round(manage[0]-(manage[0]-manage[numberofnan+1])/numberofnan*i,9)

# %%
manage=[]
first_nan = 580
numberofnan = 3
for i in range(numberofnan):
    data['c102'][first_nan+i]=0
for i in range(numberofnan+2):
    manage.append(float(data['c102'][first_nan-1+i]))
for i in range(numberofnan):
    data['c102'][first_nan+i]=np.round(manage[0]-(manage[0]-manage[numberofnan+1])/numberofnan*i,9)

# %%
manage=[]
first_nan = 563
numberofnan = 13
for i in range(numberofnan):
    data['c118'][first_nan+i]=0
for i in range(numberofnan+2):
    manage.append(float(data['c118'][first_nan-1+i]))
for i in range(numberofnan):
    data['c118'][first_nan+i]=np.round(manage[0]-(manage[0]-manage[numberofnan+1])/numberofnan*i,9)

# %%
manage=[]
first_nan = 563
numberofnan = 13
for i in range(numberofnan):
    data['c193'][first_nan+i]=0
for i in range(numberofnan+2):
    manage.append(float(data['c193'][first_nan-1+i]))
for i in range(numberofnan):
    data['c193'][first_nan+i]=np.round(manage[0]-(manage[0]-manage[numberofnan+1])/numberofnan*i,9)

# %%
manage=[]
first_nan = 563
numberofnan = 13
for i in range(numberofnan):
    data['c197'][first_nan+i]=0
for i in range(numberofnan+2):
    manage.append(float(data['c197'][first_nan-1+i]))
for i in range(numberofnan):
    data['c197'][first_nan+i]=np.round(manage[0]-(manage[0]-manage[numberofnan+1])/numberofnan*i,9)

# %%
manage=[]
first_nan = 578
numberofnan = 2
for i in range(numberofnan):
    data['c166'][first_nan+i]=0
for i in range(numberofnan+2):
    manage.append(float(data['c166'][first_nan-1+i]))
for i in range(numberofnan):
    data['c166'][first_nan+i]=np.round(manage[0]-(manage[0]-manage[numberofnan+1])/numberofnan*i,9)

# %%
correlation_matrix=data[['c51','c52','c53','c54']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.show()

# %%
q=data['c53']*data['c53']
a=a = sm.add_constant(pd.concat([data['c53'], q], axis=1))
b=data['c54']
model=sm.OLS(b,a).fit()
print(model.summary())
yp=model.predict(a)
x=np.arange(1,len(a)+1)
plt.plot(x,b,x,yp)

# %%
X=data.drop(columns=['c1','c2','c51','c52','c53','c54','c82','c110','c149','c156','c168','c169','c170','c171','c188','c189','c190','c199','c202','c204','c206','c207', 'c208', 'c209', 'c210', 'c211', 'c212', 'c213', 'c214', 'c215', 'c216', 'c217', 'c218', 'c219', 'c220', 'c221', 'c222', 'c223','c226','c229','c231','c232','c233','c234'])
y=data['c53']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=5)
dropped_vars = []
R2_values = []
dropped_vars = []
R2_values = []
X=sm.add_constant(X)
X_train = X_train.apply(pd.to_numeric, errors='coerce')
while len(X_train.columns) > 1:
    model = sm.OLS(y_train, X_train).fit()
    max_p_value = model.pvalues[1:].max()
    
    if max_p_value > 0.05:
        dropped_var = model.pvalues[1:].idxmax()
        X_train = X_train.drop(columns=[dropped_var])
        model = sm.OLS(y_train, X_train).fit()
        dropped_vars.append(dropped_var)
        R2_values.append(model.rsquared)
    else:
        break

summary_table = pd.DataFrame({
    "Dropped Variable": dropped_vars,
    "R2": R2_values
})
print(summary_table)
print(model.summary())

X_test = X_test.apply(pd.to_numeric, errors='coerce')
X_test = X_test[X_train.columns] 

y_pred_test = model.predict(X_test)
df = pd.DataFrame({'Predicted': y_pred_test.tolist(), 'Actual': y_test.tolist()})
df['error'] = (df['Predicted'] - df['Actual'])

x = np.arange(len(df['Actual']))
plt.figure(figsize=(13, 6))
plt.plot(x, df['Actual'], label='Actual')
plt.plot(x, df['Predicted'], label='Predicted')
plt.legend()

plt.show()
# Out:
#    Dropped Variable        R2
# 0               c75  0.985368
# 1              c203  0.985368
# 2              c111  0.985368
# 3              c107  0.985368
# 4              c157  0.985368
# 5              c123  0.985368
# 6               c24  0.985368
# 7               c65  0.985368
# 8              c205  0.985368
# 9              c129  0.985368
# 10              c90  0.985367
# 11              c46  0.985367
# 12             c146  0.985366
# 13              c27  0.985365
# 14              c10  0.985364
# 15             c166  0.985363
# 16             c126  0.985362
# 17             c116  0.985360
# 18              c61  0.985359
# 19             c235  0.985357
# 20              c39  0.985353
# 21             c106  0.985353
# 22              c67  0.985353
# 23             c192  0.985350
# 24             c174  0.985344
# 25              c33  0.985338
# 26              c71  0.985333
# 27              c66  0.985326
# 28             c120  0.985319
# 29              c83  0.985317
# 30              c38  0.985310
# 31             c187  0.985301
# 32              c11  0.985298
# 33             c128  0.985298
# 34               c5  0.985293
# 35               c7  0.985285
# 36             c151  0.985275
# 37             c118  0.985263
# 38             c122  0.985252
# 39              c70  0.985241
# 40              c59  0.985228
# 41             c197  0.985213
# 42             c114  0.985199
# 43             c173  0.985185
# 44              c23  0.985171
# 45             c147  0.985153
# 46             c137  0.985138
# 47              c14  0.985121
# 48             c152  0.985100
# 49              c47  0.985077
# 50              c43  0.985053
# 51             c186  0.985029
# 52              c50  0.985006
# 53              c20  0.984980
# 54             c196  0.984955
# 55              c35  0.984926
# 56              c62  0.984899
# 57              c36  0.984873
# 58             c165  0.984846
# 59              c58  0.984820
# 60             c125  0.984792
# 61             c224  0.984757
# 62              c45  0.984728
# 63             c105  0.984690
# 64             c161  0.984690
# 65             c162  0.984689
# 66             c160  0.984678
# 67             c159  0.984672
# 68              c28  0.984632
# 69              c30  0.984619
# 70             c113  0.984587
# 71             c239  0.984556
# 72             c180  0.984516
# 73             c176  0.984516
# 74               c8  0.984478
# 75             c145  0.984424
# 76              c69  0.984422
# 77              c18  0.984411
# 78              c76  0.984409
# 79             c141  0.984405
# 80             c136  0.984388
# 81             c144  0.984384
# 82              c77  0.984365
# 83              c17  0.984334
# 84               c6  0.984303
# 85             c139  0.984262
# 86              c19  0.984262
# 87             c194  0.984205
# 88               c4  0.984143
# 89              c68  0.984093
# 90             c201  0.984028
# 91             c158  0.983965
# 92              c93  0.983899
# 93             c177  0.983821
# 94             c178  0.983821
# 95             c181  0.983820
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    c53   R-squared:                       0.984
# Model:                            OLS   Adj. R-squared:                  0.982
# Method:                 Least Squares   F-statistic:                     447.3
# Date:                Mon, 13 Nov 2023   Prob (F-statistic):               0.00
# Time:                        06:12:45   Log-Likelihood:                -1009.7
# No. Observations:                 820   AIC:                             2217.
# Df Residuals:                     721   BIC:                             2684.
# Df Model:                          98
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c3             2.1147      0.988      2.141      0.033       0.175       4.054
# c9            -0.3685      0.079     -4.658      0.000      -0.524      -0.213
# c12            0.5255      0.118      4.466      0.000       0.294       0.756
# c13            0.3386      0.084      4.021      0.000       0.173       0.504
# c15            0.4349      0.107      4.061      0.000       0.225       0.645
# c16            0.4020      0.108      3.730      0.000       0.190       0.614
# c21           -0.1155      0.053     -2.161      0.031      -0.220      -0.011
# c22           -0.1099      0.048     -2.287      0.022      -0.204      -0.016
# c25           -0.4745      0.113     -4.204      0.000      -0.696      -0.253
# c26           -1.0595      0.105    -10.059      0.000      -1.266      -0.853
# c29            0.5383      0.063      8.499      0.000       0.414       0.663
# c31           -1.6993      0.186     -9.158      0.000      -2.064      -1.335
# c32            0.4841      0.088      5.489      0.000       0.311       0.657
# c34            4.6187      1.413      3.269      0.001       1.845       7.393
# c37           -0.6411      0.280     -2.292      0.022      -1.190      -0.092
# c40           10.7988      2.804      3.851      0.000       5.294      16.304
# c41           62.8678      9.217      6.821      0.000      44.772      80.963
# c42            0.6752      0.211      3.196      0.001       0.260       1.090
# c44           -0.3290      0.100     -3.279      0.001      -0.526      -0.132
# c48        -1.175e+05   1.06e+04    -11.131      0.000   -1.38e+05   -9.68e+04
# c49           11.2425      4.161      2.702      0.007       3.074      19.411
# c55          201.5789     49.188      4.098      0.000     105.009     298.149
# c56           -1.4052      0.240     -5.851      0.000      -1.877      -0.934
# c57           29.2914      3.129      9.362      0.000      23.149      35.434
# c130         -11.0669      1.855     -5.967      0.000     -14.708      -7.426
# c131          21.1193      2.980      7.088      0.000      15.269      26.969
# c132       -6507.7958    963.122     -6.757      0.000   -8398.655   -4616.937
# c150           0.5208      0.100      5.208      0.000       0.324       0.717
# c153           0.1122      0.025      4.402      0.000       0.062       0.162
# c154          -1.5023      0.369     -4.073      0.000      -2.226      -0.778
# c155           0.1919      0.054      3.565      0.000       0.086       0.298
# c163           0.0049      0.002      2.151      0.032       0.000       0.009
# c164          90.0196     10.016      8.988      0.000      70.356     109.683
# c167          13.5603      2.067      6.561      0.000       9.503      17.618
# c172           1.3251      0.442      3.001      0.003       0.458       2.192
# c175        2.439e+07   9.13e+06      2.671      0.008    6.46e+06    4.23e+07
# c179       -2.439e+07   9.13e+06     -2.671      0.008   -4.23e+07   -6.46e+06
# c182          -0.0956      0.025     -3.779      0.000      -0.145      -0.046
# c183        2.439e+07   9.13e+06      2.671      0.008    6.46e+06    4.23e+07
# c184          15.5977      2.530      6.165      0.000      10.631      20.565
# c185        -202.5304     47.387     -4.274      0.000    -295.563    -109.498
# c191          21.6007      4.088      5.284      0.000      13.576      29.626
# c193          -2.8344      0.627     -4.522      0.000      -4.065      -1.604
# c195          -1.0047      0.295     -3.410      0.001      -1.583      -0.426
# c198           0.7434      0.176      4.226      0.000       0.398       1.089
# c200        1.246e+05   1.12e+04     11.112      0.000    1.03e+05    1.47e+05
# c225        -159.7786     37.545     -4.256      0.000    -233.489     -86.068
# c227       -7386.8367    661.477    -11.167      0.000   -8685.488   -6088.185
# c228         -24.0054      2.369    -10.131      0.000     -28.657     -19.353
# c230          -0.5834      0.218     -2.676      0.008      -1.012      -0.155
# c236           0.1257      0.062      2.016      0.044       0.003       0.248
# c237           0.1874      0.094      2.003      0.046       0.004       0.371
# c238          -0.0456      0.014     -3.212      0.001      -0.073      -0.018
# c241          -1.8955      0.584     -3.247      0.001      -3.042      -0.749
# ==============================================================================
# Omnibus:                       12.722   Durbin-Watson:                   1.956
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               19.359
# Skew:                           0.111   Prob(JB):                     6.25e-05
# Kurtosis:                       3.719   Cond. No.                     1.01e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.69e-23. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
bins = [-np.inf, 5, 10, 20, np.inf]
labels = ['SAFE', 'MODERATE', '!!ALERT!!-HIGH', '!!ALERT!!-CRITICAL']
y_pred_levels = pd.cut(y_pred_test, bins=bins, labels=labels, include_lowest=True)
df_results = pd.DataFrame({'Predicted': y_pred_test, 'Level': y_pred_levels})
print(df_results)
df_results.groupby('Level').size().plot(kind='bar', title='Count of Predictions in Each Level')
plt.show()

# %%
y1=data['c53']
X1=data[['c26', 'c27', 'c28', 'c29', 'c30', 'c31', 'c32',
'c33', 'c39', 'c139', 'c142', 'c143', 'c155', 'c156', 'c157', 'c158', 'c160', 'c161', 'c162', 'c163']]
X=sm.add_constant(X)
X_train, X_test, y_train, y_test = train_test_split(X1, y1, test_size=0.2, random_state=1)
X_test = X_test.reset_index(drop=True)
y_test = y_test.reset_index(drop=True)
model = sm.OLS(y_train, X_train).fit()
dropped_vars = []
R2_values = []
while len(X.columns) > 1:
    model = sm.OLS(y_train, X_train).fit()
    max_p_value = model.pvalues[0:].max() 
    if max_p_value > 0.05:
        dropped_var = model.pvalues[0:].idxmax()
        X_train = X_train.drop(columns=[dropped_var])
        model = sm.OLS(y_train, X_train).fit()
        dropped_vars.append(dropped_var)
        R2_values.append(model.rsquared)
    else:
        break
summary_table = pd.DataFrame({
 "Dropped Variable": dropped_vars,
 "R2": R2_values
})
print(summary_table)
print(model.summary())
X_test=X_test.drop(columns = dropped_vars)
y_pred_test=model.predict(X_test)
df = pd.DataFrame({'Predicted': y_pred_test.tolist(), 'Actual': y_test.tolist()})
df['error'] = (df['Predicted']-df['Actual'])
x=[]


for i in range(len(df['Actual'])):
    x.append(i)

plt.plot(x,df['Actual'])
plt.plot(x,df['Predicted'])
plt.show()
sorted_coefficients = model.params.sort_values(ascending=False)
print(sorted_coefficients)

# %%
bins = [-np.inf, 5, 10, 20, np.inf]
labels = ['SAFE', 'MODERATE', 'HIGH ALERT!', 'CRITICAL ALERT!']
y_pred_levels = pd.cut(y_pred_test, bins=bins, labels=labels, include_lowest=True)
df_results = pd.DataFrame({'Predicted': y_pred_test, 'Level': y_pred_levels})
high_alert_indices = df_results[df_results['Level'] == 'HIGH ALERT!'].index.tolist()
critical_alert_indices = df_results[df_results['Level'] == 'CRITICAL ALERT!'].index.tolist()
print(df_results)
df_results.groupby('Level').size().plot(kind='bar', title='Count of Predictions in Each Level')
plt.show()
high_alert_indices

# %%
epsilon=0.01 
threshold=10 # Change as desired
for i in high_alert_indices:
    while (model.predict(X_test.iloc[i]) > threshold).any():
        X_test.loc[i, 'c30'] -= epsilon
for i in critical_alert_indices:
    while (model.predict(X_test.iloc[i]) > threshold).any():
        X_test.loc[i, 'c30'] -= epsilon

# %%
y_pred_test=model.predict(X_test)

# %%
bins = [-np.inf, 5, 10, 20, np.inf]
labels = ['SAFE', 'MODERATE', 'HIGH ALERT!', 'CRITICAL ALERT!']
y_pred_levels = pd.cut(y_pred_test, bins=bins, labels=labels, include_lowest=True)
df_results = pd.DataFrame({'Predicted': y_pred_test, 'Level': y_pred_levels})
high_alert_indices = df_results[df_results['Level'] == 'HIGH ALERT!'].index.tolist()
critical_alert_indices = df_results[df_results['Level'] == 'CRITICAL ALERT!'].index.tolist()
print(df_results)
df_results.groupby('Level').size().plot(kind='bar', title='Count of Predictions in Each Level')
plt.show()

# %%
X=data.drop(columns=['c1','c2','c82','c110','c149','c156','c168','c169','c170','c171','c188','c189','c190','c199','c202','c204','c206','c207', 'c208', 'c209', 'c210', 'c211', 'c212', 'c213', 'c214', 'c215', 'c216', 'c217', 'c218', 'c219', 'c220', 'c221', 'c222', 'c223','c226','c229','c231','c232','c233','c234','c241'])
y=data['c241']
X=sm.add_constant(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=9)
dropped_vars = []
R2_values = []
dropped_vars = []
R2_values = []
X=sm.add_constant(X)
X_train = X_train.apply(pd.to_numeric, errors='coerce')
while len(X_train.columns) > 1:
    model = sm.OLS(y_train, X_train).fit()
    max_p_value = model.pvalues[1:].max()
    
    if max_p_value > 0.05:
        dropped_var = model.pvalues[1:].idxmax()
        X_train = X_train.drop(columns=[dropped_var])
        model = sm.OLS(y_train, X_train).fit()
        dropped_vars.append(dropped_var)
        R2_values.append(model.rsquared)
    else:
        break

summary_table = pd.DataFrame({
    "Dropped Variable": dropped_vars,
    "R2": R2_values
})
print(summary_table)
print(model.summary())

# Convert data types to numeric in X_test
X_test = X_test.apply(pd.to_numeric, errors='coerce')
X_test = X_test[X_train.columns]  # Make sure the test set has the same columns as the trained model

y_pred_test = model.predict(X_test)
df = pd.DataFrame({'Predicted': y_pred_test.tolist(), 'Actual': y_test.tolist()})
df['error'] = (df['Predicted'] - df['Actual'])

x = np.arange(len(df['Actual']))
plt.figure(figsize=(13, 6))
plt.plot(x, df['Actual'], label='Actual')
plt.plot(x, df['Predicted'], label='Predicted')
plt.legend()
plt.show()
sorted_coefficients = model.params.abs().sort_values(ascending=False)
print(sorted_coefficients)
sorted_coefficients[:10].plot(kind='bar')
# Out:
#     Dropped Variable        R2
# 0                c70  0.999293
# 1                c10  0.999293
# 2               c106  0.999293
# 3               c158  0.999293
# 4                c55  0.999293
# 5               c185  0.999293
# 6                c17  0.999293
# 7               c155  0.999293
# 8                c60  0.999293
# 9               c129  0.999292
# 10               c54  0.999292
# 11               c58  0.999292
# 12              c115  0.999292
# 13               c84  0.999292
# 14              c143  0.999292
# 15               c35  0.999292
# 16                c3  0.999292
# 17              c186  0.999292
# 18               c64  0.999292
# 19               c40  0.999292
# 20              c227  0.999292
# 21              c125  0.999292
# 22               c20  0.999292
# 23               c65  0.999292
# 24              c180  0.999292
# 25              c122  0.999292
# 26               c45  0.999291
# 27              c111  0.999291
# 28               c19  0.999291
# 29               c32  0.999291
# 30               c34  0.999291
# 31              c127  0.999291
# 32               c24  0.999290
# 33               c12  0.999290
# 34              c160  0.999290
# 35               c18  0.999290
# 36              c167  0.999290
# 37              c159  0.999289
# 38              c162  0.999289
# 39              c161  0.999289
# 40               c44  0.999289
# 41              c117  0.999288
# 42               c72  0.999288
# 43               c22  0.999287
# 44              c236  0.999287
# 45               c66  0.999286
# 46              c166  0.999285
# 47              c128  0.999285
# 48              c118  0.999285
# 49              c137  0.999284
# 50               c69  0.999283
# 51              c172  0.999283
# 52              c124  0.999282
# 53               c53  0.999281
# 54               c36  0.999280
# 55              c113  0.999279
# 56              c187  0.999278
# 57              c126  0.999277
# 58               c21  0.999276
# 59               c80  0.999274
# 60              c130  0.999274
# 61               c85  0.999273
# 62               c74  0.999271
# 63               c15  0.999270
# 64              c157  0.999269
# 65               c90  0.999267
# 66              c105  0.999266
# 67              c108  0.999266
# 68               c68  0.999265
# 69               c27  0.999264
# 70              c182  0.999262
# 71               c56  0.999260
# 72              c200  0.999260
# 73               c48  0.999259
# 74               c83  0.999259
# 75              c228  0.999257
# 76              c104  0.999256
# 77              c120  0.999254
# 78               c41  0.999252
# 79               c28  0.999250
# 80               c30  0.999249
# 81              c109  0.999248
# 82              c144  0.999245
# 83              c134  0.999243
# 84               c97  0.999241
# 85              c133  0.999239
# 86              c179  0.999236
# 87              c114  0.999233
# 88               c63  0.999231
# 89              c235  0.999229
# 90              c139  0.999226
# 91               c13  0.999224
# 92               c23  0.999221
# 93              c152  0.999218
# 94               c77  0.999215
# 95              c154  0.999213
# 96              c184  0.999209
# 97              c121  0.999206
# 98              c197  0.999203
# 99              c193  0.999200
# 100             c142  0.999197
# 101              c46  0.999195
# 102              c31  0.999191
# 103              c25  0.999191
# 104             c141  0.999189
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   c241   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                     9505.
# Date:                Mon, 13 Nov 2023   Prob (F-statistic):               0.00
# Time:                        04:53:04   Log-Likelihood:                 1921.1
# No. Observations:                 820   AIC:                            -3652.
# Df Residuals:                     725   BIC:                            -3205.
# Df Model:                          94
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -4.728e+06    2.3e+06     -2.054      0.040   -9.25e+06    -2.1e+05
# c4            -0.1340      0.010    -13.703      0.000      -0.153      -0.115
# c5             0.0195      0.006      3.405      0.001       0.008       0.031
# c6             0.0121      0.003      4.743      0.000       0.007       0.017
# c7             0.0803      0.026      3.115      0.002       0.030       0.131
# c8            -0.0418      0.006     -7.471      0.000      -0.053      -0.031
# c9            -0.0319      0.006     -5.462      0.000      -0.043      -0.020
# c11           -0.0896      0.002    -37.374      0.000      -0.094      -0.085
# c14            0.0201      0.008      2.635      0.009       0.005       0.035
# c16           -0.0156      0.003     -5.325      0.000      -0.021      -0.010
# c26           -0.0363      0.007     -4.918      0.000      -0.051      -0.022
# c29            0.0109      0.003      4.329      0.000       0.006       0.016
# c33            0.0432      0.009      4.879      0.000       0.026       0.061
# c37           -0.0424      0.006     -6.633      0.000      -0.055      -0.030
# c38           -0.2208      0.047     -4.654      0.000      -0.314      -0.128
# c39           -4.6754      2.013     -2.323      0.020      -8.626      -0.724
# c42           -0.0228      0.006     -4.141      0.000      -0.034      -0.012
# c43            0.0078      0.003      2.235      0.026       0.001       0.015
# c47            0.5997      0.102      5.900      0.000       0.400       0.799
# c49           -0.5339      0.090     -5.922      0.000      -0.711      -0.357
# c50        -4.578e+06   2.23e+06     -2.055      0.040   -8.95e+06   -2.04e+05
# c51            0.0040      0.001      3.999      0.000       0.002       0.006
# c52           -0.0072      0.002     -4.183      0.000      -0.011      -0.004
# c57           -0.4264      0.065     -6.537      0.000      -0.554      -0.298
# c59           -0.0456      0.015     -2.996      0.003      -0.075      -0.016
# c61           -0.0195      0.005     -3.626      0.000      -0.030      -0.009
# c62            0.0203      0.005      4.254      0.000       0.011       0.030
# c67           -0.2235      0.051     -4.403      0.000      -0.323      -0.124
# c71           -0.0222      0.007     -3.231      0.001      -0.036      -0.009
# c73            0.0202      0.006      3.526      0.000       0.009       0.031
# c75            0.0044      0.000     10.321      0.000       0.004       0.005
# c76           -0.0538      0.012     -4.391      0.000      -0.078      -0.030
# c78         -205.1955     15.375    -13.346      0.000    -235.380    -175.011
# c79          -91.1267     14.716     -6.192      0.000    -120.017     -62.236
# c81         -240.9764     41.975     -5.741      0.000    -323.384    -158.569
# c237     4.431830e-03
# c75      4.421955e-03
# c51      4.011009e-03
# c102     3.902971e-03
# c239     2.619201e-03
# c148     2.051458e-03
# c153     1.850975e-03
# c238     1.497615e-03
# c146     9.173690e-04
# c147     3.847558e-04
# c163     3.256014e-04
# dtype: float64
# <AxesSubplot:>

# %%
X=data.drop(columns=['c1','c2','c82','c110','c149','c156','c168','c169','c170','c171','c188','c189','c190','c199','c202','c204','c206','c207', 'c208', 'c209', 'c210', 'c211', 'c212', 'c213', 'c214', 'c215', 'c216', 'c217', 'c218', 'c219', 'c220', 'c221', 'c222', 'c223','c226','c229','c231','c232','c233','c234','c241','c26', 'c27', 'c28', 'c29', 'c30', 'c31', 'c32',
'c33', 'c39', 'c139', 'c142', 'c143', 'c155', 'c156', 'c157', 'c158', 'c160', 'c161', 'c162', 'c163'])
y=data['c241']
X=sm.add_constant(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=9)
dropped_vars = []
R2_values = []
dropped_vars = []
R2_values = []
X=sm.add_constant(X)
X_train = X_train.apply(pd.to_numeric, errors='coerce')
while len(X_train.columns) > 1:
    model = sm.OLS(y_train, X_train).fit()
    max_p_value = model.pvalues[1:].max()
    
    if max_p_value > 0.05:
        dropped_var = model.pvalues[1:].idxmax()
        X_train = X_train.drop(columns=[dropped_var])
        model = sm.OLS(y_train, X_train).fit()
        dropped_vars.append(dropped_var)
        R2_values.append(model.rsquared)
    else:
        break

summary_table = pd.DataFrame({
    "Dropped Variable": dropped_vars,
    "R2": R2_values
})
print(summary_table)
print(model.summary())

# Convert data types to numeric in X_test
X_test = X_test.apply(pd.to_numeric, errors='coerce')
X_test = X_test[X_train.columns]  # Make sure the test set has the same columns as the trained model

y_pred_test = model.predict(X_test)
df = pd.DataFrame({'Predicted': y_pred_test.tolist(), 'Actual': y_test.tolist()})
df['error'] = (df['Predicted'] - df['Actual'])

x = np.arange(len(df['Actual']))
plt.figure(figsize=(13, 6))
plt.plot(x, df['Actual'], label='Actual')
plt.plot(x, df['Predicted'], label='Predicted')
plt.legend()
plt.show()
sorted_coefficients = model.params.abs().sort_values(ascending=False)
print(sorted_coefficients)
sorted_coefficients[:20].plot(kind='bar')
# Out:
#    Dropped Variable        R2
# 0               c58  0.999235
# 1               c18  0.999235
# 2               c15  0.999235
# 3              c152  0.999235
# 4              c105  0.999235
# 5              c118  0.999235
# 6               c20  0.999235
# 7               c35  0.999235
# 8              c185  0.999235
# 9               c74  0.999235
# 10             c111  0.999235
# 11             c125  0.999235
# 12             c180  0.999235
# 13              c60  0.999234
# 14              c44  0.999234
# 15              c22  0.999234
# 16              c55  0.999234
# 17             c187  0.999234
# 18              c72  0.999234
# 19              c70  0.999234
# 20              c54  0.999233
# 21              c98  0.999233
# 22              c84  0.999233
# 23             c122  0.999233
# 24              c10  0.999232
# 25              c69  0.999232
# 26             c128  0.999232
# 27             c228  0.999231
# 28             c109  0.999231
# 29             c113  0.999230
# 30             c145  0.999230
# 31              c85  0.999229
# 32              c12  0.999229
# 33             c104  0.999228
# 34             c174  0.999228
# 35             c154  0.999227
# 36              c41  0.999226
# 37              c53  0.999226
# 38             c112  0.999225
# 39             c117  0.999224
# 40             c127  0.999224
# 41              c34  0.999224
# 42               c6  0.999223
# 43              c56  0.999222
# 44              c68  0.999221
# 45              c45  0.999220
# 46              c83  0.999220
# 47             c120  0.999219
# 48             c115  0.999218
# 49              c36  0.999217
# 50              c65  0.999216
# 51             c133  0.999214
# 52              c14  0.999213
# 53              c66  0.999211
# 54              c21  0.999210
# 55             c173  0.999208
# 56             c166  0.999206
# 57             c179  0.999205
# 58              c80  0.999203
# 59             c130  0.999203
# 60              c91  0.999201
# 61             c164  0.999199
# 62              c86  0.999196
# 63              c97  0.999194
# 64              c61  0.999192
# 65              c24  0.999190
# 66             c144  0.999189
# 67              c17  0.999189
# 68               c3  0.999187
# 69             c141  0.999187
# 70              c76  0.999186
# 71              c77  0.999185
# 72             c137  0.999183
# 73              c50  0.999180
# 74             c227  0.999180
# 75              c48  0.999180
# 76             c159  0.999178
# 77             c200  0.999175
# 78             c167  0.999172
# 79             c172  0.999169
# 80             c182  0.999169
# 81             c177  0.999168
# 82              c23  0.999164
# 83              c73  0.999161
# 84             c184  0.999157
# 85              c46  0.999157
# 86             c230  0.999152
# 87             c238  0.999148
# 88             c239  0.999145
# 89              c47  0.999142
# 90             c147  0.999138
# 91             c146  0.999137
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   c241   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                     9617.
# Date:                Mon, 13 Nov 2023   Prob (F-statistic):               0.00
# Time:                        05:13:43   Log-Likelihood:                 1895.4
# No. Observations:                 820   AIC:                            -3613.
# Df Residuals:                     731   BIC:                            -3194.
# Df Model:                          88
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        242.6245     47.377      5.121      0.000     149.613     335.636
# c4            -0.1288      0.010    -12.519      0.000      -0.149      -0.109
# c5             0.0194      0.006      3.335      0.001       0.008       0.031
# c7             0.0984      0.025      3.926      0.000       0.049       0.148
# c8            -0.0533      0.005    -10.611      0.000      -0.063      -0.043
# c9            -0.0368      0.005     -6.879      0.000      -0.047      -0.026
# c11           -0.0895      0.003    -34.479      0.000      -0.095      -0.084
# c13           -0.0086      0.002     -4.508      0.000      -0.012      -0.005
# c16           -0.0284      0.003     -8.280      0.000      -0.035      -0.022
# c19           -0.0176      0.003     -5.602      0.000      -0.024      -0.011
# c25            0.0175      0.003      6.211      0.000       0.012       0.023
# c37           -0.0401      0.007     -5.985      0.000      -0.053      -0.027
# c38           -0.2263      0.053     -4.270      0.000      -0.330      -0.122
# c40            0.2673      0.041      6.496      0.000       0.187       0.348
# c42           -0.0234      0.006     -4.088      0.000      -0.035      -0.012
# c43            0.0095      0.004      2.518      0.012       0.002       0.017
# c49           -0.0536      0.010     -5.437      0.000      -0.073      -0.034
# c51            0.0044      0.001      4.295      0.000       0.002       0.006
# c52           -0.0088      0.002     -4.985      0.000      -0.012      -0.005
# c57           -0.6559      0.092     -7.115      0.000      -0.837      -0.475
# c59           -0.0343      0.016     -2.135      0.033      -0.066      -0.003
# c181          -0.0163      0.004     -3.782      0.000      -0.025      -0.008
# c183           0.2665      0.017     16.121      0.000       0.234       0.299
# c186          -5.3630      1.894     -2.831      0.005      -9.082      -1.644
# c191           0.3873      0.164      2.362      0.018       0.065       0.709
# c192           0.2465      0.030      8.279      0.000       0.188       0.305
# c193           0.1345      0.034      3.903      0.000       0.067       0.202
# c194          -0.2677      0.042     -6.419      0.000      -0.350      -0.186
# c195          -0.1005      0.010     -9.724      0.000      -0.121      -0.080
# c196          -0.0307      0.005     -5.603      0.000      -0.041      -0.020
# c197          -0.0399      0.017     -2.374      0.018      -0.073      -0.007
# c198           0.1305      0.029      4.568      0.000       0.074       0.187
# c201         -11.6876      1.155    -10.122      0.000     -13.954      -9.421
# c203           0.0724      0.028      2.541      0.011       0.016       0.128
# c205           0.9889      0.060     16.531      0.000       0.871       1.106
# c224         -12.1431      4.803     -2.528      0.012     -21.573      -2.714
# c225        -166.7861     10.172    -16.396      0.000    -186.757    -146.816
# c235          -1.0848      0.386     -2.808      0.005      -1.843      -0.326
# c236           0.0045      0.001      3.023      0.003       0.002       0.007
# c237          -0.0056      0.001     -3.891      0.000      -0.008      -0.003
# ==============================================================================
# Omnibus:                      275.784   Durbin-Watson:                   2.018
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5058.461
# Skew:                           1.035   Prob(JB):                         0.00
# Kurtosis:                      14.990   Cond. No.                     3.54e+08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.54e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# const    242.624521
# c78      208.674553
# c225     166.786088
# c81      117.363056
# c79       91.807789
# c132      90.856379
# c90       87.878078
# c123      84.549609
# c108      82.351043
# c92       48.052640
# c94       20.054970
# c99       12.904995
# c224      12.143050
# c201      11.687574
# c87        8.687203
# c93        8.177147
# c186       5.362988
# c64        4.840209
# c88        4.725419
# c151       2.960423
# c126       2.687304
# c96        2.612963
# c95        1.255749
# c235       1.084787
# c205       0.988860
# c103       0.786665
# c100       0.674293
# c57        0.655853
# c191       0.387260
# c119       0.345043
# c67        0.311900
# c134       0.306627
# c89        0.276975
# c175       0.268885
# c194       0.267728
# c40        0.267304
# c183       0.266478
# c192       0.246500
# c38        0.226297
# c176       0.146788
# c131       0.138987
# c193       0.134475
# c198       0.130467
# c4         0.128804
# c195       0.100539
# c7         0.098369
# c11        0.089530
# c101       0.087327
# c203       0.072396
# c107       0.056261
# c114       0.054817
# c49        0.053560
# c8         0.053254
# c106       0.047338
# c62        0.043136
# c37        0.040058
# c197       0.039911
# c63        0.037598
# c9         0.036825
# c59        0.034348
# c116       0.031369
# c165       0.030919
# c196       0.030663
# c16        0.028395
# c42        0.023381
# c71        0.021932
# c140       0.021068
# c5         0.019377
# c19        0.017616
# c25        0.017482
# c129       0.016324
# c181       0.016275
# c124       0.014941
# c135       0.014575
# c150       0.014342
# c43        0.009525
# c52        0.008811
# c13        0.008627
# c136       0.006391
# c237       0.005578
# c138       0.005402
# c178       0.004786
# c236       0.004533
# c51        0.004407
# c75        0.004377
# c102       0.003455
# c148       0.003008
# c153       0.002153
# c121       0.001704
# dtype: float64
# <AxesSubplot:>
